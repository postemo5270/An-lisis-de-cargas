# %% [markdown]
# <a href="https://colab.research.google.com/github/postemo5270/An-lisis-de-cargas/blob/main/MC_ELE_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =============================================================================
# CONEXIÓN CON GITHUB Y CARGA DEL BACKEND
# Usuario: postemo5270 | Repo: DNC-MC-DinaT_58_0
# =============================================================================
import sys
import os

# Nombre exacto del repositorio
REPO_NAME = 'DNC-MC-DinaT_58_0'
USER = 'postemo5270'
URL_REPO = f'https://github.com/{USER}/{REPO_NAME}.git'

# 1. Limpieza (Borrar versión anterior si existe para actualizar cambios)
if os.path.exists(REPO_NAME):
    print(f"🔄 Actualizando repositorio {REPO_NAME}...")
    # !rm -rf {REPO_NAME}
else:
    print(f"⬇️ Descargando repositorio {REPO_NAME}...")

# 2. Clonar el repositorio
# !git clone {URL_REPO}

# 3. Agregar la carpeta al sistema para poder importar
sys.path.append(f'/content/{REPO_NAME}')

# 4. Importar el Backend (Base de Datos y Lógica)
try:
    # Importamos las tablas de cables para la auditoría
    from backend import BD_CABLES_CU, BD_CABLES_AL
    print("\n✅ CONEXIÓN EXITOSA: Backend cargado y listo.")
    print(f"   - Base de Datos Cobre: {len(BD_CABLES_CU)} referencias cargadas.")
    print(f"   - Base de Datos Aluminio: {len(BD_CABLES_AL)} referencias cargadas.")
except ImportError:
    print("\n❌ ERROR CRÍTICO: No se encontró el archivo 'backend.py' en el repositorio.")
    print(f"   Verifica que hayas creado el archivo 'backend.py' dentro de {REPO_NAME} en GitHub.")
# Out:
# 🔄 Actualizando repositorio DNC-MC-DinaT_58_0...
# Cloning into 'DNC-MC-DinaT_58_0'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 7 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), 6.21 KiB | 6.21 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
#
# ✅ CONEXIÓN EXITOSA: Backend cargado y listo.
#    - Base de Datos Cobre: 15 referencias cargadas.
#    - Base de Datos Aluminio: 15 referencias cargadas.
